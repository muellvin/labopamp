# %%
import numpy as np
import matplotlib.pyplot as plt

R1 = np.array([[4.48, 0.448, 0.11,0.11],
               [4.48, 0.4, 109, 109],
               [4.64, 0.38, 488, 488],
               [4.56, 0.16, 2750, 2750]])

R10 = np.array([[4.48, 4.56, 0.11, 0.11],
                [4.64, 3.92, 26.7, 26.7],
                [4.64, 1.52, 184, 184],
               [4.64, 0.44, 630, 630],
               [4.56, 0.144, 2230, 2230]])

R22 = np.array([[4.48, 10.4, 0.11, 0.11],
                [4.64, 9.2, 12.2, 12.2],
                [4.56, 6.8, 38, 38],
                [4.64, 1.76, 160, 160],
                [4.6, 0.48, 606, 606],
                [4.56, 0.26, 1320, 1320]])

R33 = np.array([[4.48, 15.2, 0.11,0.11],
                [4.64, 13.2, 13, 13],
               [4.64, 8.8,31.6,31.6],
               [4.64, 3.68, 75, 75],
               [4.64, 1.12, 263, 263],
               [4.64, 0.4, 895, 895]])
R47 = np.array([[4.48, 21.6, 0.11, 0.11],
                [4.40, 20.8, 0.773, 0.773],
               [4.56, 16.6, 16.5, 16.5],
               [4.56, 9, 31.6, 31.6],
               [4.64, 4.0, 82, 82],
               [4.64, 1.56, 187, 187]])

plt.loglog(R1[:,2], R1[:,1]/R1[:,0])
plt.loglog(R10[:,2], R10[:,1]/R10[:,0])
plt.loglog(R22[:,2], R22[:,1]/R22[:,0])
plt.loglog(R33[:,2], R33[:,1]/R33[:,0])
plt.loglog(R47[:,2], R47[:,1]/R47[:,0])
plt.show()

# %%
#measurement of the resonance curve
#freq, Umax, Umin, RMS for one
#109.8, 5.6, -6.4, 4.05

#measuring freq and RMS
measurement = np.array([[59.7, 2.72],
                        [54, 2.61],
                        [45, 2.54],
                        [36, 2.51],
                        [27, 2.47],
                        [18.4, 2.46],
                        [11.6, 2.40],
                        [65.1, 2.79],
                        [73, 2.88],
                        [76, 3],
                       [85.5, 3.11],
                       [90.50, 3.23],
                       [95, 3.38],
                       [99.4, 3.55],
                       [105.5, 3.83],
                       [110, 4.06],
                       [115.1, 4.27],
                       [120.5, 4.51],
                       [125.5, 4.72],
                       [130.5, 4.98],
                       [135, 5.36],
                       [140.1, 5.74],
                       [146, 6.13],
                       [150, 6.29],
                       [155, 6.27],
                       [160, 6],
                       [165.8, 5.62],
                       [171.2, 5.17],
                       [176.1, 4.78],
                        [181, 4.33],
                       [185.5, 3.99],
                       [191.6, 3.53],
                       [195.7, 3.25],
                       [200, 2.88],
                       [210, 2.42],
                       [224, 2],
                       [238, 1.64],
                       [251.9, 1.38],
                       [274, 1.09],
                       [297, 0.89]])
plt.scatter(measurement[:,0], measurement[:,1])
